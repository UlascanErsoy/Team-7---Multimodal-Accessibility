# %%
DATA_PATH = "scatter_data"

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import os

def plot_four(x , y):

    plt.scatter(x, y)
    plt.grid(True)


    plt.tight_layout()

# %%
x = np.arange(0, 10, 1) 
y = np.array([
    0.0,
    0.0,
    0.0,
    1.0,
    1.0,
    1.0,
    1.0,
    0.0,
    0.0,
    0.0
])

#y = np.exp(1 - x * 0.75)
#y = y - y.min()
#y /= y.max()

y = y[::-1]
description = "square wave in the middle"

plot_four(x, y)

# %%
NUM = max([int(name.split(".")[0]) for name in os.listdir(DATA_PATH)]) + 1

dd = {
    "x":x.tolist(),
    "y":y.tolist(),
    "description":description
}
#open(os.path.join(DATA_PATH, f"{NUM}.json"), "w").write(json.dumps(dd, indent=2))
# Out:
# 19
